# %%
# %%file requirements.txt
# datasets==1.16.1
# pycountry==20.7.3
# wandb==0.12.7
# sentence-transformers==2.1.0
# Out:
# Writing requirements.txt

# %%
pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 298 kB 5.1 MB/s
#      |████████████████████████████████| 10.1 MB 50.1 MB/s
#      |████████████████████████████████| 1.7 MB 42.4 MB/s
#      |████████████████████████████████| 78 kB 6.8 MB/s
#      |████████████████████████████████| 1.1 MB 57.8 MB/s
#      |████████████████████████████████| 59 kB 6.2 MB/s
#      |████████████████████████████████| 132 kB 55.9 MB/s
#      |████████████████████████████████| 243 kB 55.6 MB/s
#      |████████████████████████████████| 180 kB 50.3 MB/s
#      |████████████████████████████████| 97 kB 6.4 MB/s
#      |████████████████████████████████| 140 kB 56.1 MB/s
#      |████████████████████████████████| 3.1 MB 37.2 MB/s
#      |████████████████████████████████| 3.3 MB 39.7 MB/s
#      |████████████████████████████████| 1.2 MB 58.5 MB/s
#      |████████████████████████████████| 63 kB 1.7 MB/s
#      |████████████████████████████████| 895 kB 55.2 MB/s
#      |████████████████████████████████| 596 kB 73.0 MB/s
#      |████████████████████████████████| 160 kB 52.1 MB/s
#      |████████████████████████████████| 271 kB 67.4 MB/s
#      |████████████████████████████████| 192 kB 62.9 MB/s
#   Building wheel for pycountry (setup.py) ... done
#   Building wheel for sentence-transformers (setup.py) ... done
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done

# %%
import traceback
import warnings
from typing import List

import numpy as np
import pandas as pd
import pycountry
import torch
import wandb
from datasets import load_dataset
from tqdm.auto import tqdm
from sentence_transformers import util

# %% [markdown]
# # Embedding

# %%
# initialize

# %%
pip install -q git+https://github.com/gmatt/sister.git@ea3b7adcd3c780a3b2390f8170673035d73d4c1c
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 753.2 MB 9.3 kB/s
#      |████████████████████████████████| 674 kB 56.9 MB/s
#      |████████████████████████████████| 68 kB 5.6 MB/s
#      |████████████████████████████████| 21.5 MB 1.3 MB/s
#      |████████████████████████████████| 24.2 MB 1.4 MB/s
#      |████████████████████████████████| 14.6 MB 185 kB/s
#      |████████████████████████████████| 17.1 MB 190 kB/s
#      |████████████████████████████████| 5.6 MB 38.5 MB/s
#   Building wheel for sister (PEP 517) ... done
#   Building wheel for fasttext (setup.py) ... done
#   Building wheel for progressbar (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.11.1+cu111 requires torch==1.10.0, but you have torch 1.5.1 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.5.1 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.5.1 which is incompatible.
# sentence-transformers 2.1.0 requires tokenizers>=0.10.3, but you have tokenizers 0.7.0 which is incompatible.
# sentence-transformers 2.1.0 requires torch>=1.6.0, but you have torch 1.5.1 which is incompatible.
# sentence-transformers 2.1.0 requires transformers<5.0.0,>=4.6.0, but you have transformers 2.11.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
# Downloading fasttext models manually, and putting them where sister expects
# them, since the sister downloader hangs, it never finishes.
# Yes, there must be a better way to do it, but I've alrady spent way too much
# time trying to find it.

# %%
# !mkdir -p fasttext/fasttext

# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.simple.zip
# !unzip wiki.simple.zip -d fasttext/fasttext/en
# !mv wiki.simple.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.simple.zip | md5sum | cut -d' ' -f1)

# %env lang be
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang bg
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang cs
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang et
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang hr
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang hu
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang hy
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang lt
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang mk
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang pl
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang ro
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang ru
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang sl
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang sr
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)

# %env lang uk
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip
# !unzip wiki.$lang.zip -d fasttext/fasttext/$lang
# !mv wiki.$lang.zip fasttext/$(echo -n https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.$lang.zip | md5sum | cut -d' ' -f1)
# Out:
# --2021-11-28 09:55:18--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.simple.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 172.67.9.4, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2618496202 (2.4G) [application/zip]
# Saving to: ‘wiki.simple.zip’
#
# wiki.simple.zip     100%[===================>]   2.44G  23.4MB/s    in 1m 48s
#
# 2021-11-28 09:57:06 (23.2 MB/s) - ‘wiki.simple.zip’ saved [2618496202/2618496202]
#
# Archive:  wiki.simple.zip
#   inflating: fasttext/fasttext/en/wiki.simple.vec
#   inflating: fasttext/fasttext/en/wiki.simple.bin
# env: lang=be
# --2021-11-28 09:57:38--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.be.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3075385975 (2.9G) [application/zip]
# Saving to: ‘wiki.be.zip’
#
# wiki.be.zip         100%[===================>]   2.86G  24.8MB/s    in 1m 59s
#
# 2021-11-28 09:59:37 (24.7 MB/s) - ‘wiki.be.zip’ saved [3075385975/3075385975]
#
# Archive:  wiki.be.zip
#   inflating: fasttext/fasttext/be/wiki.be.vec
#   inflating: fasttext/fasttext/be/wiki.be.bin
# env: lang=bg
# --2021-11-28 10:00:17--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.bg.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3352878796 (3.1G) [application/zip]
# Saving to: ‘wiki.bg.zip’
#
# wiki.bg.zip         100%[===================>]   3.12G  14.8MB/s    in 8m 35s
#
# 2021-11-28 10:08:52 (6.21 MB/s) - ‘wiki.bg.zip’ saved [3352878796/3352878796]
#
# Archive:  wiki.bg.zip
#   inflating: fasttext/fasttext/bg/wiki.bg.vec
#   inflating: fasttext/fasttext/bg/wiki.bg.bin
# env: lang=cs
# --2021-11-28 10:09:39--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.cs.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4298783945 (4.0G) [application/zip]
# Saving to: ‘wiki.cs.zip’
#
# wiki.cs.zip         100%[===================>]   4.00G  21.7MB/s    in 3m 10s
#
# 2021-11-28 10:12:50 (21.6 MB/s) - ‘wiki.cs.zip’ saved [4298783945/4298783945]
#
# Archive:  wiki.cs.zip
#   inflating: fasttext/fasttext/cs/wiki.cs.vec
#   inflating: fasttext/fasttext/cs/wiki.cs.bin
# env: lang=et
# --2021-11-28 10:13:53--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.et.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.75.142, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3336759235 (3.1G) [application/zip]
# Saving to: ‘wiki.et.zip’
#
# wiki.et.zip         100%[===================>]   3.11G  21.8MB/s    in 2m 26s
#
# 2021-11-28 10:16:20 (21.7 MB/s) - ‘wiki.et.zip’ saved [3336759235/3336759235]
#
# Archive:  wiki.et.zip
#   inflating: fasttext/fasttext/et/wiki.et.vec
#   inflating: fasttext/fasttext/et/wiki.et.bin
# env: lang=hr
# --2021-11-28 10:17:04--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.hr.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3735645088 (3.5G) [application/zip]
# Saving to: ‘wiki.hr.zip’
#
# wiki.hr.zip         100%[===================>]   3.48G  23.8MB/s    in 2m 31s
#
# 2021-11-28 10:19:35 (23.6 MB/s) - ‘wiki.hr.zip’ saved [3735645088/3735645088]
#
# Archive:  wiki.hr.zip
#   inflating: fasttext/fasttext/hr/wiki.hr.vec
#   inflating: fasttext/fasttext/hr/wiki.hr.bin
# env: lang=hu
# --2021-11-28 10:20:24--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.hu.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.75.142, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4832950684 (4.5G) [application/zip]
# Saving to: ‘wiki.hu.zip’
#
# wiki.hu.zip         100%[===================>]   4.50G  21.2MB/s    in 3m 41s
#
# 2021-11-28 10:24:05 (20.9 MB/s) - ‘wiki.hu.zip’ saved [4832950684/4832950684]
#
# Archive:  wiki.hu.zip
#   inflating: fasttext/fasttext/hu/wiki.hu.vec
#   inflating: fasttext/fasttext/hu/wiki.hu.bin
# env: lang=hy
# --2021-11-28 10:25:16--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.hy.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.75.142, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3349740286 (3.1G) [application/zip]
# Saving to: ‘wiki.hy.zip’
#
# wiki.hy.zip         100%[===================>]   3.12G  21.8MB/s    in 2m 28s
#
# 2021-11-28 10:27:44 (21.6 MB/s) - ‘wiki.hy.zip’ saved [3349740286/3349740286]
#
# Archive:  wiki.hy.zip
#   inflating: fasttext/fasttext/hy/wiki.hy.vec
#   inflating: fasttext/fasttext/hy/wiki.hy.bin
# env: lang=lt
# --2021-11-28 10:28:27--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.lt.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3261917202 (3.0G) [application/zip]
# Saving to: ‘wiki.lt.zip’
#
# wiki.lt.zip         100%[===================>]   3.04G  21.2MB/s    in 2m 27s
#
# 2021-11-28 10:30:55 (21.2 MB/s) - ‘wiki.lt.zip’ saved [3261917202/3261917202]
#
# Archive:  wiki.lt.zip
#   inflating: fasttext/fasttext/lt/wiki.lt.vec
#   inflating: fasttext/fasttext/lt/wiki.lt.bin
# env: lang=mk
# --2021-11-28 10:31:37--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.mk.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2835725886 (2.6G) [application/zip]
# Saving to: ‘wiki.mk.zip’
#
# wiki.mk.zip         100%[===================>]   2.64G  16.5MB/s    in 2m 45s
#
# 2021-11-28 10:34:22 (16.4 MB/s) - ‘wiki.mk.zip’ saved [2835725886/2835725886]
#
# Archive:  wiki.mk.zip
#   inflating: fasttext/fasttext/mk/wiki.mk.vec
#   inflating: fasttext/fasttext/mk/wiki.mk.bin
# env: lang=pl
# --2021-11-28 10:34:59--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.pl.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 104.22.74.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5598792162 (5.2G) [application/zip]
# Saving to: ‘wiki.pl.zip’
#
# wiki.pl.zip         100%[===================>]   5.21G  24.6MB/s    in 3m 44s
#
# 2021-11-28 10:38:44 (23.9 MB/s) - ‘wiki.pl.zip’ saved [5598792162/5598792162]
#
# Archive:  wiki.pl.zip
#   inflating: fasttext/fasttext/pl/wiki.pl.vec
#   inflating: fasttext/fasttext/pl/wiki.pl.bin
# env: lang=ro
# --2021-11-28 10:40:04--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.ro.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 172.67.9.4, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3417555991 (3.2G) [application/zip]
# Saving to: ‘wiki.ro.zip’
#
# wiki.ro.zip         100%[===================>]   3.18G  24.7MB/s    in 2m 13s
#
# 2021-11-28 10:42:18 (24.5 MB/s) - ‘wiki.ro.zip’ saved [3417555991/3417555991]
#
# Archive:  wiki.ro.zip
#   inflating: fasttext/fasttext/ro/wiki.ro.vec
#   inflating: fasttext/fasttext/ro/wiki.ro.bin
# env: lang=ru
# --2021-11-28 10:43:02--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.ru.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8344906764 (7.8G) [application/zip]
# Saving to: ‘wiki.ru.zip’
#
# wiki.ru.zip         100%[===================>]   7.77G  24.1MB/s    in 5m 31s
#
# 2021-11-28 10:48:34 (24.1 MB/s) - ‘wiki.ru.zip’ saved [8344906764/8344906764]
#
# Archive:  wiki.ru.zip
#   inflating: fasttext/fasttext/ru/wiki.ru.vec
#   inflating: fasttext/fasttext/ru/wiki.ru.bin
# env: lang=sl
# --2021-11-28 10:50:52--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.sl.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3178083415 (3.0G) [application/zip]
# Saving to: ‘wiki.sl.zip’
#
# wiki.sl.zip         100%[===================>]   2.96G  21.9MB/s    in 2m 20s
#
# 2021-11-28 10:53:13 (21.7 MB/s) - ‘wiki.sl.zip’ saved [3178083415/3178083415]
#
# Archive:  wiki.sl.zip
#   inflating: fasttext/fasttext/sl/wiki.sl.vec
#   inflating: fasttext/fasttext/sl/wiki.sl.bin
# env: lang=sr
# --2021-11-28 10:54:04--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.sr.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3736548396 (3.5G) [application/zip]
# Saving to: ‘wiki.sr.zip’
#
# wiki.sr.zip         100%[===================>]   3.48G  23.5MB/s    in 2m 33s
#
# 2021-11-28 10:56:38 (23.4 MB/s) - ‘wiki.sr.zip’ saved [3736548396/3736548396]
#
# Archive:  wiki.sr.zip
#   inflating: fasttext/fasttext/sr/wiki.sr.vec
#   inflating: fasttext/fasttext/sr/wiki.sr.bin
# env: lang=uk
# --2021-11-28 10:57:27--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.uk.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 172.67.9.4, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5217692977 (4.9G) [application/zip]
# Saving to: ‘wiki.uk.zip’
#
# wiki.uk.zip         100%[===================>]   4.86G  8.97MB/s    in 13m 27s
#
# 2021-11-28 11:10:54 (6.17 MB/s) - ‘wiki.uk.zip’ saved [5217692977/5217692977]
#
# Archive:  wiki.uk.zip
#   inflating: fasttext/fasttext/uk/wiki.uk.vec
#   inflating: fasttext/fasttext/uk/wiki.uk.bin

# %%
# !mkdir -p ~/.sister/cache/
# !mv fasttext ~/.sister/cache/
# !mv ~/.sister/cache/fasttext ~/.sister/cache/_dl_cache

# %%
from sister import MeanEmbedding
from sister.word_embedders import FasttextEmbedding

# %%
# embed

def embed(sentences: List[str], lang: str) -> np.ndarray:
    embedder = MeanEmbedding(lang, word_embedder=FasttextEmbedding(lang))
    return [embedder.embed(x) for x in sentences]

# %% [markdown]
# # Execution

# %%
config = wandb.config

config.embedder = "fasttext"
config.name = f"tapaco-{config.embedder}"

# %%
wandb.login()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
wandb.init(
      entity="eenlp",
      project="paraphrase_detection",
      job_type=f"create-dataset",
      name=f"create-tapaco-{config.embedder}"
)
# Out:
# wandb: Currently logged in as: matts (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/eenlp/paraphrase_detection/runs/xzzu70ap" target="_blank">create-tapaco-fasttext</a></strong> to <a href="https://wandb.ai/eenlp/paraphrase_detection" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/eenlp/paraphrase_detection/runs/xzzu70ap?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# DATASET_ONLY_FIRST_N = 20_000
DATASET_ONLY_FIRST_N = 10_000

config.DATASET_ONLY_FIRST_N = DATASET_ONLY_FIRST_N

dataset_name = "tapaco"

dataset = load_dataset("tapaco", "all_languages")
df = dataset["train"].to_pandas()

df["paraphrase_set_id"] = df["paraphrase_set_id"].astype(int)

languages_to_keep = [
    "be",  # Belarusian
    "bg",  # Bulgarian
    "cs",  # Czech
    "en",  # English
    "et",  # Estonian
    "hr",  # Croatian
    "hu",  # Hungarian
    "hy",  # Armenian
    "lt",  # Lithuanian
    "mk",  # Macedonian
    "pl",  # Polish
    "ro",  # Romanian
    "ru",  # Russian
    "sl",  # Slovenian
    "sr",  # Serbian
    "uk",  # Ukrainian
]

df = df[df["language"].isin(languages_to_keep)]
assert len(languages_to_keep) == len(
    df["language"].unique()
), "Count of filtered languages doesn't match, probably a typo in 'languages_to_keep'?"

# paraphrase_set_id = 0 seems to mean "unassigned".
df = df[df["paraphrase_set_id"] != 0].copy()

# We need to generate example pairs somehow.
# As of the current version of the code, 50% of the generated examples are true paraphrases (label = 1),
# 25% are chosen from the most similar non-paraphrases (label = 0),
# and 25% is random negative examples (label = 0).

result = []
np.random.seed(0)
for language, df_language in tqdm(df.groupby("language"), "language", position=0):
    try:
        language_name = pycountry.languages.get(alpha_2=language).name

        df_language = df_language[:DATASET_ONLY_FIRST_N]

        df_language["embeddings"] = embed(df_language["paraphrase"].to_list(), language)

        for paraphrase_set_id, df_set in tqdm(
            df_language.groupby("paraphrase_set_id"),
            "paraphrase_set_id",
            position=1,
        ):
            if len(df_set) <= 1:
                continue

            df_negatives = df_language[
                df_language["paraphrase_set_id"] != paraphrase_set_id
            ]

            for row in df_set.itertuples():
                result.append(
                    {
                        "sentence1": row.paraphrase,
                        "sentence2": np.random.choice(
                            df_set[df_set.index != row.Index]["paraphrase"]
                        ),
                        "label": 1,
                        "lang": language_name,
                    }
                )

                # TODO this can sample the same pair twice, consider fixing it
                result.append(
                    {
                        "sentence1": row.paraphrase,
                        "sentence2": np.random.choice(
                            df_set[df_set.index != row.Index]["paraphrase"]
                        ),
                        "label": 1,
                        "lang": language_name,
                    }
                )

                # similar negative
                query_embedding = row.embeddings
                corpus_embeddings = df_negatives["embeddings"]
                cos_scores = util.pytorch_cos_sim(query_embedding, np.stack(corpus_embeddings.values))[0]
                top_results = torch.topk(cos_scores, k=1)

                result.append(
                    {
                        "sentence1": row.paraphrase,
                        "sentence2": df_negatives.iloc[top_results[1][0].item()]["paraphrase"],
                        "label": 0,
                        "lang": language_name,
                    }
                )

                # random negative
                result.append(
                    {
                        "sentence1": row.paraphrase,
                        "sentence2": np.random.choice(df_negatives["paraphrase"]),
                        "label": 0,
                        "lang": language_name,
                    }
                )
    except KeyboardInterrupt:
        raise
    # except:
    #     warnings.warn(traceback.format_exc())
    #     continue

result = pd.DataFrame(result)
result["source"] = dataset_name
result["split"] = "train"

artifact = wandb.Artifact(name=config.name, type="tapaco-dataset")
artifact.add(wandb.Table(dataframe=result), "data")
wandb.run.log_artifact(artifact)
# Out:
# Downloading:   0%|          | 0.00/3.02k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.69k [00:00<?, ?B/s]
# Downloading and preparing dataset tapaco/all_languages (download: 30.72 MiB, generated: 155.26 MiB, post-processed: Unknown size, total: 185.98 MiB) to /root/.cache/huggingface/datasets/tapaco/all_languages/1.0.0/71d200534b520a174927a8f0479c06220a0a6fb5201a84ebfce19006c6354698...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/32.2M [00:00<?, ?B/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0 examples [00:00, ? examples/s]
# Dataset tapaco downloaded and prepared to /root/.cache/huggingface/datasets/tapaco/all_languages/1.0.0/71d200534b520a174927a8f0479c06220a0a6fb5201a84ebfce19006c6354698. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# language:   0%|          | 0/16 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/645 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/2638 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/2831 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/2256 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/112 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/230 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/2605 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/240 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/3465 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/3934 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/3547 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/940 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/1942 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/309 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/3236 [00:00<?, ?it/s]
# Loading model...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# paraphrase_set_id:   0%|          | 0/2699 [00:00<?, ?it/s]
# WARNING:root:Truncating wandb.Table object to 200000 rows.

# %%
wandb.run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 1510... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 30.52MB of 30.52MB uploaded (0.26MB deduped)\r'), FloatProgress(value=1.0, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# </div><div class="wandb-col">
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 1 other file(s)
# <br/>Synced <strong style="color:#cdcd00">create-tapaco-fasttext</strong>: <a href="https://wandb.ai/eenlp/paraphrase_detection/runs/xzzu70ap" target="_blank">https://wandb.ai/eenlp/paraphrase_detection/runs/xzzu70ap</a><br/>
# Find logs at: <code>./wandb/run-20211128_112529-xzzu70ap/logs</code><br/>
